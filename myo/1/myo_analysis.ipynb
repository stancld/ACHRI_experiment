# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm


# %matplotlib inline

# %%
emg = pd.read_csv('emg-1582293935.csv')
acc = pd.read_csv('accelerometer-1582293935.csv')
gyro = pd.read_csv('gyro-1582293935.csv')
eda = pd.read_csv('EDA.csv')

gyro.head()
# Out:
#           timestamp       x       y        z
# 0  1582293935129137  7.5625  0.9375  11.8750
# 1  1582293935144098  3.3750 -2.3125  11.6250
# 2  1582293935167035  1.5625 -3.5625   9.3125
# 3  1582293935189973  0.8125 -3.6875   6.6250
# 4  1582293935204934  0.8125 -3.9375   4.1250

# %%
fig, ax = plt.subplots(14, 1, figsize = (10, 20))
for i in range(1, 9):
    exec("ax[i-1].plot(emg.emg{:.0f})".format(i))
    
ax[8].plot(acc.x, color = 'orange')
ax[8].set_title('accelerometer')
ax[9].plot(acc.y, color = 'orange')
ax[9].set_title('accelerometer')
ax[10].plot(acc.z, color = 'orange')
ax[10].set_title('accelerometer')

ax[11].plot(gyro.x, color = 'green')
ax[11].set_title('gyro')
ax[12].plot(gyro.y, color = 'green')
ax[12].set_title('gyro')
ax[13].plot(gyro.z, color = 'green')
ax[13].set_title('gyro')
# Out:
# Text(0.5, 1.0, 'gyro')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-bdec0ad284d7> in <module>
#       1 X = sm.add_constant(acc)
# ----> 2 model = sm.OLS(emg.emg1, X)
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     857                  **kwargs):
#     858         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 859                                   hasconst=hasconst, **kwargs)
#     860         if "weights" in self._init_keys:
#     861             self._init_keys.remove("weights")
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     700             weights = weights.squeeze()
#     701         super(WLS, self).__init__(endog, exog, missing=missing,
# ...
